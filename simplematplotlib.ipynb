# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjuadhikari14/simplematplotlib/blob/main/simplematplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[2,3,5,7,11]

# %%
plt.plot(x,y)
plt.title('prime number plot ')
plt.xlabel('label')
plt.ylabel('prime number ')
plt.show()

# %%
y1=[2,3,5,7,11]
z1=[1,4,6,8,12]

# %%
plt.plot(x,y1,label='primenumber')
plt.plot(x,z1,label='random number')
plt.title('graph plot between different numbers')
plt.legend()
plt.show()

# %%
### customizing these datasets

# %%
plt.plot(x, y1, color='r', linestyle='--', label='primenumber')
plt.plot(x, z1, color='g', linestyle=':', label='randomnumber')
plt.legend()
plt.show()

# %%
categories=['A','B','C','D','E','F']
values=[2,5,6,8,3,10]
plt.bar(categories,values)


plt.show()

# %%
plt.plot(x, y)
plt.grid(False)
plt.annotate('prime at (3,5)',
             xy=(3, 5),
             xytext=(4, 6),
             arrowprops=dict(facecolor='black'))
plt.show()

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [2, 3, 5, 7, 11]

# %%
plt.plot(x,y)
plt.xticks(ticks=[1,2,3,4,5],labels=['one','two','three','four','five'])
plt.yticks(ticks=[2,3,5,7,11],labels=['p1','p2','p3','p4','p5'])
plt.show()

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [2, 3, 5, 7, 11]

# %%
plt.scatter(x,y)
plt.title('scatter plot of data x & y')
plt.show()

# %%
data=[10,23,45,67,78,90]

# %%
plt.hist(data, color='red', bins=3, edgecolor='black')
plt.title('Histogram')
plt.show()

# %%
### Data for scatter

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

# %%
##Data for historam

# %%
z=[10,20,30,40,50,60,70]

# %%
plt.scatter(x,y,color='blue')
plt.hist(z,bins=4,color='red',edgecolor='black',alpha=0.3)
plt.title('overlay scatter and histogram plot')
plt.legend()
plt.show()
# Out:
# <ipython-input-22-20502fb590fa>:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np

# %%
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.hexbin(x,y,gridsize=30,cmap='Blues')
plt.colorbar(label='density')

plt.show()

# %%
a=[1,2,3,4,5]
b=[1,4,9,16,25]

# %%
plt.plot(a,b,marker='o')
plt.annotate('Peak',xy=(4.75,25),arrowprops=dict(facecolor='black'))
plt.text(1,1,'start point',fontsize=12,color='green')
plt.show()

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)
y=np.sin(x)

# %%
fig_width=12
fig_height=fig_width/1.618
plt.figure(figsize=(fig_width,fig_height))
plt.plot(x,y,'g-',lw=2,label='sine wave')
plt.title('dynamic figure size and aspect ratio')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.grid(True)
plt.show()
